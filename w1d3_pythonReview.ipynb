# %% [markdown]
# ## Week 1, Day 3
#
# **This class will cover:**
# - Markdown language
# - Expressions
# - Comments
# - Variables
# - Data Types
# - Conditional Statements

# %% [markdown]
# ## Markdown language

# %% [markdown]
# Markdown is an easy-to-use markup language that is used with plain text to add formatting elements (headings, bulleted lists, URLs) to plain text without the use of a formal text editor or the use of HTML tags.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Big header
# ## medium header
# ### small header
#
# **This is some bold stuff**
#
# *and I am italic*
#
# 1. I am item number 1
# 2. I am item number 2
#
# - I am an unordered list
# - I am an unordered list\
# - I am an unordered list
#
# [this is my website](http://www.google.com)

# %% [markdown]
# **Excercise 1:** Make the following words links
#
# **The most popular *social media* platforms are:**
# - [Facebook](https://www.facebook.com)
# - [Twitter](https://www.twitter.com)
# - [Instagram](https://www.instagram.com)

# %% [markdown]
# ## Basic commands
# - Printing
# - Variables and values
# - Mathematical operations + quotient and remainder
# - String operation
# - Asking user for input
# - Comments

# %%
# a character value

# %%
# assign a numerical variable

# %%
# assign a string variable

# %%
# assign a float variable

# %%
# assign a string variable

# %%
#print one of the variables

# %%
# print another variable

# %%
# find out the type of the variable

# %%
# find out the type of another variable

# %%
# what happens when you add two string variables?

# %%
# what happens when you add two integer variables?

# %%
# print some variables

# %%
# how do you include a variable in a string

# %%
# create an variable form an input

# %%
# text that input

# %%
# include the variable in a print statement with other string

# %% [markdown]
# ### **Excercise 2:** Create the following
#
# 1. Ask for first name and assign to a variable
# 2. Ask for last name and assign to a variable
# 3. Add the first name and lastname to a variable
# 4. Print out the full name

# %% [markdown]
# ## Conditional Execution

# %% [markdown]
# ### Boolean expressions

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# assign variables

# %%
# check if its greater than or equal to 10

# %%
# check if its greater than or equal to the other variable

# %%
# check if its not equal

# %% [markdown]
# ### Logical operators
# **and**, **or**, and **not**

# %%
#the opposite of True

# %%
# what is False?

# %%
# lets assign some variables

# %%
# lets try OR

# %%
# AND

# %%
# NOT

# %% [markdown]
# ## Conditional Execution (IF Statements)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# set a variable


# check if its greater than 0 and print a statemetn

# %%
# print multiple variables

# %%
# check if x is greater than 0 and print a statemetn

# %%
# write and if statement to check if c is the largest variable

# %% [markdown]
# ## Alternative excution (IF, ELSE Statements)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# what is modulo?

# %%
# see if x is the modulo print its even, if not odd

# %% [markdown]
# ## Chained conditionals (IF, ELIF, ELSE Statements)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#with these statements compare these two variables

# %% [markdown]
# ## Nested conditionals

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#compare two sets of variables x,y and c,b

# %% [markdown]
# **Excercise 3**: Create the following
#
# Write a program to prompt for a score between 0.0 and
# 1.0. If the score is out of range, print an error message. If the score is
# between 0.0 and 1.0, print a grade using the following table:
# - \>= 0.8 Excelent
# - \>= 0.5 Average
# - \< 0.5 Poor
